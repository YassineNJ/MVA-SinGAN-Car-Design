# %%
# !git clone -b Yassine https://github.com/YassineNJ/SinGAN-Project.git
# !pip install torch==1.4.0 torchvision==0.5.0
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/SinGAN-Project
# Out:
# ...
# fatal: destination path 'SinGAN-Project' already exists and is not an empty directory.
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/SinGAN-Project

# %%
for f in os.listdir('train_images/'):
  # !python main_train.py --input_dir train_images/ --input_name {f}
# Out:
# Random Seed:  8405
# trained model already exist
# Random Seed:  2126
# GeneratorConcatSkip2CleanAdd(
#   (head): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#     (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (body): Sequential(
#     (block1): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (block2): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (block3): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
# ...

# %%
for scale in range(1,6):
  for train_image in os.listdir('sketchs/'):
    if train_image in os.listdir('TrainedModels/'):
      for f in os.listdir('sketchs/'+train_image):
        # !python paint2image.py --ref_dir sketchs/{train_image}/ --ref_name {f} --input_dir  train_images/ --input_name  {train_image}.jpg --paint_start_scale {scale}
# Out:
# Random Seed:  6912
# Random Seed:  3171
# Random Seed:  301
# Random Seed:  7025
# Random Seed:  8557
# Random Seed:  3827
# Random Seed:  1841
# Random Seed:  7493
# Random Seed:  2017
# Random Seed:  1893
# Random Seed:  8235
# Random Seed:  1025
# Random Seed:  3693
# Random Seed:  5288
# Random Seed:  2485
# Random Seed:  6470
# Random Seed:  6952
# Random Seed:  3167
# Random Seed:  5548
# Random Seed:  7530
# Random Seed:  7463
# Random Seed:  6774
# Random Seed:  5550
# Random Seed:  5391
# Random Seed:  3620
# Random Seed:  1509
# Random Seed:  4536
# Random Seed:  2895
# Random Seed:  8126
# Random Seed:  3138
# Random Seed:  3404
# Random Seed:  6697
# Random Seed:  590
# Random Seed:  9046
# Random Seed:  8360
# Random Seed:  7727
# Random Seed:  6067
# Random Seed:  1310
# Random Seed:  500
# Random Seed:  8978
# Random Seed:  9155
# Random Seed:  5120
# Random Seed:  4286
# Random Seed:  1639
# Random Seed:  2455
# Random Seed:  1131
# Random Seed:  1913
# ...

# %%
# !zip -r /content/output.zip /content/Output
# !zip -r /content/TrainedModels.zip /content/TrainedModels

# from google.colab import files
# files.download("/content/output.zip")
# files.download("/content/TrainedModels.zip")
# Out:
#   adding: content/Output/ (stored 0%)
#   adding: content/Output/Paint2image/ (stored 0%)
#   adding: content/Output/Paint2image/ferari_blue/ (stored 0%)
#   adding: content/Output/Paint2image/ferari_blue/ferari_blue_sketch_white_mer_out/ (stored 0%)
#   adding: content/Output/Paint2image/ferari_blue/ferari_blue_sketch_white_mer_out/start_scale=5.png (stored 0%)
#   adding: content/Output/Paint2image/ferari_blue/ferari_blue_sketch_white_mer_out/start_scale=4.png (stored 0%)
#   adding: content/Output/Paint2image/ferari_blue/ferari_blue_sketch_white_mer_out/start_scale=1.png (stored 0%)
#   adding: content/Output/Paint2image/ferari_blue/ferari_blue_sketch_white_mer_out/start_scale=2.png (stored 0%)
#   adding: content/Output/Paint2image/ferari_blue/ferari_blue_sketch_white_mer_out/start_scale=3.png (stored 0%)
#   adding: content/Output/Paint2image/ferari_blue/ferari_blue_sketch_lam_green_out/ (stored 0%)
# ...
